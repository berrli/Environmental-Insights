# %% [markdown]
# # SynthHAPPE

# %%
# %%html
# <style>
#   /* 1) The wrapper enforces the “height = X% of width” */
#   .iframe‐wrapper {
#     position: relative;
#     width: 100%;           /* full-width */
#     padding-bottom: 55%;   /* ← 55% of width = height */
#     height: 0;             /* collapse the wrapper’s own height (padding-bottom will “create” the height) */
#   }
#
#   /* 2) The iframe is absolutely positioned to fill the wrapper */
#   .iframe‐wrapper iframe {
#     position: absolute;
#     top: 0;
#     left: 0;
#     width: 100%;    /* fill 100% of wrapper’s width */
#     height: 100%;   /* fill 100% of wrapper’s (calculated) height */
#     border: 0;
#   }
# </style>
#
# <div class="iframe‐wrapper">
#   <iframe
#     src="../../_static/synthhappe_no2.html"
#     scrolling="no"
#     allowfullscreen
#   ></iframe>
# </div>
# Out:
# <style>
#   /* 1) The wrapper enforces the “height = X% of width” */
#   .iframe‐wrapper {
#     position: relative;
#     width: 100%;           /* full-width */
#     padding-bottom: 55%;   /* ← 55% of width = height */
#     height: 0;             /* collapse the wrapper’s own height (padding-bottom will “create” the height) */
#   }
#
#   /* 2) The iframe is absolutely positioned to fill the wrapper */
#   .iframe‐wrapper iframe {
#     position: absolute;
#     top: 0;
#     left: 0;
#     width: 100%;    /* fill 100% of wrapper’s width */
#     height: 100%;   /* fill 100% of wrapper’s (calculated) height */
#     border: 0;
#   }
# </style>
#
# <div class="iframe‐wrapper">
#   <iframe
#     src="../../_static/synthhappe_no2.html"
#     scrolling="no"
#     allowfullscreen
#   ></iframe>
# </div>

# %% [markdown]
# # SynthHAPPE (Synthetic Hourly Air Pollution Prediction Averages for England)
#
# ## Environmental Insights: Democratizing access to ambient air pollution data and predictive analytics with an open-source Python package
#
# The dataset presented here builds on our previous framework ([A framework for scalable ambient air pollution concentration
# estimation](https://doi.org/10.1017/eds.2025.9)) by introducing “typical day” or aggregated data. Rather than offering only raw, large-scale time series, this supplementary data condenses hourly measurements into representative diurnal cycles for each month and day of the week, greatly simplifying scenario modeling and stakeholder engagement. By focusing on typical patterns, users can efficiently investigate interventions and visualize how different factors—such as traffic emissions or meteorological changes—might influence air quality in everyday conditions. This dataset is associated with the peer-reviewed research article [Environmental Insights: Democratizing access to ambient air pollution data and predictive analytics with an open-source Python package](
# https://doi.org/10.1016/j.envsoft.2024.106131).
#
# Alongside these averaged “typical day” profiles, the underlying [Python package](https://github.com/berrli/Environmental-Insights) also provides user-friendly functions for fetching, filtering, and visualizing full-resolution hourly estimates. This dual-layered approach—offering both condensed and precise data—aims to accommodate diverse research and policy needs. Whether users require comprehensive, hour-by-hour values or streamlined snapshots of typical behavior, the package empowers them to work with high-resolution spatial data, investigate air quality forecasts, and integrate pollution insights into broader public health and environmental studies.
#
# ## Dataset Purpose
#
# This dataset empowers diverse stakeholders—including researchers, policymakers, urban planners, and public health authorities—by offering aggregated “typical day” air quality estimates rather than detailed, hourly-resolution data. By condensing raw observations into representative daily cycles for each month and day of the week, it simplifies high-level scenario planning, supports targeted interventions, and aids in more accessible discussions around urban resilience and environmental justice.
#
# Despite its streamlined format, the dataset remains grounded in robust machine-learning predictions, ensuring reliability for health impact studies, policy decisions, and broader environmental assessments. It is readily available online for quick retrieval and integration into various analytical or operational workflows. With this aggregated approach, users can efficiently evaluate pollution patterns, design interventions, and make informed decisions that promote healthier, more sustainable urban environments.
#
# For questions regarding this dataset please reach out to [Liam J Berrisford](https://orcid.org/0000-0001-6578-3497).
#
# ### Air Pollution (Target Vector) Dataset Overview
#
# The dataset focuses on “typical day” (aggregated) estimates for key ambient air pollutants Nitrogen Dioxide (NO~2~),  Nitrogen Oxides (NO~x~), Nitric Oxide (NO), Ozone (O~3~), Particulate Matter with a diameter of 10 μm or less (PM~10~), Particulate Matter with a diameter of 2.5 μm or less (PM~2.5~), and Sulphur Dioxide (SO~2~). Rather than providing the original raw time series, these aggregated data capture representative daily cycles for each month and day of the week, simplifying the exploration of typical patterns and variations in pollutant levels.
#
# Estimates are produced at the mean, as well as at the 0.05, 0.5, and 0.95 quantiles to illuminate both typical and extreme conditions. The mean offers a central reference, while quantile-based predictions highlight variability and potential outliers—enabling stakeholders to assess health risks, plan interventions, and form strategies for managing episodes of elevated pollution.
#
# ### Feature Vector Dataset Overview
#
# This aggregated “typical day” dataset is derived from the same broad set of feature vectors originally used to estimate ambient air pollution concentrations across England. Each feature captures environmental conditions or human activities that influence pollutant levels—ranging from meteorological factors like wind speed and temperature to emissions proxies such as traffic intensity and land-use classifications. These choices reflect well-established scientific evidence linking each variable to air pollutant formation, dispersion, or accumulation.
#
# By condensing the extensive hourly data into representative daily cycles for each month and day of the week, the model integrates these feature vectors in a streamlined manner. This approach allows users to explore how core determinants of air quality interact under typical conditions, facilitating scenario planning, policy discussion, and broader environmental assessments without the complexity of handling full-resolution time series.
#
# ## Data Description
#
# | **Data description**     |                                                                  |
# |--------------------------|------------------------------------------------------------------|
# | **Data type**            | Point Estimates                                                  |
# | **Projection**           | EPSG:3395 WGS 84 / World Mercator                                |
# | **Horizontal coverage**  | England                                                          |
# | **Horizontal resolution**| 1km^2^                                                           |
# | **Vertical coverage**    | Surface only                                                     |
# | **Vertical resolution**  | Single layer                                                     |
# | **Temporal coverage**    | Synthetic Aggregate                                              |
# | **Temporal resolution**  | Hourly (aggregated to typical monthly/weekday hourly profiles)   |
# | **File format**          | NetCDF                                                           |
# | **Update frequency**     | Static                                                           |
#
#
# ## Coordinate Variables
#
# | **Name**   | **Units** | **Description**                             |
# |------------|-----------|---------------------------------------------|
# | Easting    | m         | Easting of centroid (EPSG:3395)             |
# | Northing   | m         | Northing of centroid (EPSG:3395)            |
#
#
# Each NetCDF file is indexed by (Northing, Easting).
#
# Each NetCDF file name specifies the Month, Day, and Hour of the aggregated scenario (e.g., Month_1-Day_Friday-Hour_0.nc). Additionally, these details are mirrored in the file’s attributes, ensuring both the file name and metadata clearly indicate which “typical” month, day, and hour the data represent.
#
# ## Main Variables
#
# ### Output Variables
#
# | **Name**                       | **Units**   | **Description**                                                                                                     |
# |--------------------------------|-------------|---------------------------------------------------------------------------------------------------------------------|
# | UK Model Grid ID               | –           | Unique identifier for each grid in the UK model, synthetic monitoring station locations are based on grid centroids.|
# | no Prediction 0.05 Quantile    | µg/m^3^     | Estimated 5th percentile of modelled NO concentration.                                                              |
# | no Prediction 0.5 Quantile     | µg/m^3^     | Estimated 50th percentile (median) of modelled NO concentration.                                                    |
# | no Prediction 0.95 Quantile    | µg/m^3^     | Estimated 95th percentile of modelled NO concentration.                                                             |
# | no Prediction Mean             | µg/m^3^     | Estimated mean of modelled NO concentration.                                                                        |
# | no2 Prediction 0.05 Quantile   | µg/m^3^     | Estimated 5th percentile of modelled NO~2~ concentration.                                                           |
# | no2 Prediction 0.5 Quantile    | µg/m^3^     | Estimated 50th percentile (median) of modelled NO~2~ concentration.                                                 |
# | no2 Prediction 0.95 Quantile   | µg/m^3^     | Estimated 95th percentile of modelled NO~2~ concentration.                                                          |
# | no2 Prediction Mean            | µg/m^3^     | Estimated mean of modelled NO~2~ concentration.                                                                     |
# | nox Prediction 0.05 Quantile   | µg/m^3^     | Estimated 5th percentile of modelled NO~x~ concentration.                                                           |
# | nox Prediction 0.5 Quantile    | µg/m^3^     | Estimated 50th percentile (median) of modelled NO~x~ concentration.                                                 |
# | nox Prediction 0.95 Quantile   | µg/m^3^     | Estimated 95th percentile of modelled NO~x~ concentration.                                                          |
# | nox Prediction Mean            | µg/m^3^     | Estimated mean of modelled NO~x~ concentration.                                                                     |
# | o3 Prediction 0.05 Quantile    | µg/m^3^     | Estimated 5th percentile of modelled O~3~ concentration.                                                            |
# | o3 Prediction 0.5 Quantile     | µg/m^3^     | Estimated 50th percentile (median) of modelled O~3~ concentration.                                                  |
# | o3 Prediction 0.95 Quantile    | µg/m^3^     | Estimated 95th percentile of modelled O~3~ concentration.                                                           |
# | o3 Prediction Mean             | µg/m^3^     | Estimated mean of modelled O~3~ concentration.                                                                      |
# | pm10 Prediction 0.05 Quantile  | µg/m^3^     | Estimated 5th percentile of modelled PM~10~ concentration.                                                          |
# | pm10 Prediction 0.5 Quantile   | µg/m^3^     | Estimated 50th percentile (median) of modelled PM~10~ concentration.                                                |
# | pm10 Prediction 0.95 Quantile  | µg/m^3^     | Estimated 95th percentile of modelled PM~10~ concentration.                                                         |
# | pm10 Prediction Mean           | µg/m^3^     | Estimated mean of modelled PM~10~ concentration.                                                                    |
# | pm2.5 Prediction 0.05 Quantile | µg/m^3^     | Estimated 5th percentile of modelled PM~2.5~ concentration.                                                         |
# | pm2.5 Prediction 0.5 Quantile  | µg/m^3^     | Estimated 50th percentile (median) of modelled PM~2.5~ concentration.                                               |
# | pm2.5 Prediction 0.95 Quantile | µg/m^3^     | Estimated 95th percentile of modelled PM~2.5~ concentration.                                                        |
# | pm2.5 Prediction Mean          | µg/m^3^     | Estimated mean of modelled PM~2.5~ concentration.                                                                   |
# | so2 Prediction 0.05 Quantile   | µg/m^3^     | Estimated 5th percentile of modelled SO~2~ concentration.                                                           |
# | so2 Prediction 0.5 Quantile    | µg/m^3^     | Estimated 50th percentile (median) of modelled SO~2~ concentration.                                                 |
# | so2 Prediction 0.95 Quantile   | µg/m^3^     | Estimated 95th percentile of modelled SO~2~ concentration.                                                          |
# | so2 Prediction Mean            | µg/m^3^     | Estimated mean of modelled SO~2~ concentration.                                                                     |
#
# ### Input Variables
# | **Name**                                   | **Units**     | **Description**                                                                                                                                                      |
# |--------------------------------------------|---------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 100m U Component of Wind                   | m/s           | East–west wind component at 100 m above ground level.                                                                                                                |
# | 100m V Component of Wind                   | m/s           | North–south wind component at 100 m above ground level.                                                                                                              |
# | 10m U Component of Wind                    | m/s           | East–west wind component at 10 m above ground level.                                                                                                                 |
# | 10m V Component of Wind                    | m/s           | North–south wind component at 10 m above ground level.                                                                                                               |
# | 2m Dewpoint Temperature                    | K             | Temperature at which air becomes saturated, measured at 2 m above ground level.                                                                                      |
# | 2m Temperature                             | K             | Air temperature at 2 m above ground level.                                                                                                                           |
# | Boundary Layer Height                      | m             | Height of the atmospheric boundary layer above ground level.                                                                                                         |
# | Downward UV Radiation at the Surface       | W/m^2^        | Downward ultraviolet radiant flux received at Earth’s surface.                                                                                                       |
# | Instantaneous 10m Wind Gust                | m/s           | Peak wind gust speed observed at 10 m AGL over a short time interval.                                                                                                |
# | Surface Pressure                           | hPa           | Atmospheric pressure at ground level.                                                                                                                                |
# | Total Column Rain Water                    | kg/m^2^       | Vertically integrated amount of rain water in a column of air above the surface.                                                                                     |
# | Sentinel 5P AAI                            | -             | Absorbing Aerosol Index (AAI), indicating the presence of UV-absorbing aerosols in the atmosphere.                                                                   |
# | Sentinel 5P CO                             | mol/m^2^      | Total column amount of carbon monoxide (CO) retrieved from Sentinel‑5P.                                                                                              |
# | Sentinel 5P HCHO                           | mol/m^2^      | Total column amount of formaldehyde (HCHO) retrieved from Sentinel‑5P.                                                                                               |
# | Sentinel 5P NO2                            | mol/m^2^      | Tropospheric column amount of nitrogen dioxide (NO₂) from Sentinel‑5P.                                                                                               |
# | Sentinel 5P O3                             | mol/m^2^      | Total column ozone (O₃) retrieved by Sentinel‑5P.                                                                                     |
# | Day of Week Number                         | -             | Integer representing the weekday, for example 0 (Monday )– 6 (Sunday).                                                                                               |
# | Hour Number                                | -             | Hour of the day on a 24-hour clock, for example 0 (midnight) – 23 (11 pm).                                                                                           |
# | Month Number                               | -             | Integer representing the month, for example 1 (January) – 12 (December).                                                                                             |
# | Week Number                                | -             | Integer denoting the ISO week number (1-53)                                                                                                                          |
# | Bicycle Score                              | -             | Hourly traffic-flow score for bicycles in each 1 km^2^ grid, aggregated from DfT AADF data and temporally distributed via the UK Time Use Survey.                    |
# | Bus and Coach Score                        | -             | Hourly traffic-flow score for buses and coaches in each 1 km^2^ grid, aggregated from DfT AADF data and temporally distributed via the UK Time Use Survey.           |
# | Car and Taxi Score                         | -             | Hourly traffic-flow score for cars and taxis in each 1 km^2^ grid, aggregated from DfT AADF data and temporally distributed via the UK Time Use Survey.              |
# | HGV Score                                  | -             | Hourly traffic-flow score for heavy goods vehicles (HGVs) in each 1 km^2^ grid, aggregated from DfT AADF data and temporally distributed via the UK Time Use Survey. |
# | LGV Score                                  | -             | Hourly traffic-flow score for light goods vehicles (LGVs) in each 1 km^2^ grid, aggregated from DfT AADF data and temporally distributed via the UK Time Use Survey. |
# | Acid grassland                             | -             | Fraction of the 1 km^2^ grid area classified as Acid grassland, derived from UKCEH 25 m Land Cover Maps.                                                             |
# | Arable and Horticulture                    | -             | Fraction of the 1 km^2^ grid area classified as Arable and Horticulture, derived from UKCEH 25 m Land Cover Maps.                                                    |
# | Bog                                        | -             | Fraction of the 1 km^2^ grid area classified as Bog, derived from UKCEH 25 m Land Cover Maps.                                                                        |
# | Broadleaved woodland                       | -             | Fraction of the 1 km^2^ grid area classified as Broadleaved woodland, derived from UKCEH 25 m Land Cover Maps.                                                       |
# | Calcareous Grassland                       | -             | Fraction of the 1 km^2^ grid area classified as Calcareous Grassland, derived from UKCEH 25 m Land Cover Maps.                                                       |
# | Coniferous Woodland                        | -             | Fraction of the 1 km^2^ grid area classified as Coniferous Woodland, derived from UKCEH 25 m Land Cover Maps.                                                        |
# | Fen Marsh and Swamp                        | -             | Fraction of the 1 km^2^ grid area classified as Fen, Marsh, or Swamp, derived from UKCEH 25 m Land Cover Maps.                                                       |
# | Freshwater                                 | -             | Fraction of the 1 km^2^ grid area covered by Freshwater, derived from UKCEH 25 m Land Cover Maps.                                                                    |
# | Heather                                    | -             | Fraction of the 1 km^2^ grid area classified as Heather, derived from UKCEH 25 m Land Cover Maps.                                                                    |
# | Heather grassland                          | -             | Fraction of the 1 km^2^ grid area classified as Heather grassland, derived from UKCEH 25 m Land Cover Maps.                                                          |
# | Improved Grassland                         | -             | Fraction of the 1 km^2^ grid area classified as Improved Grassland, derived from UKCEH 25 m Land Cover Maps.                                                         |
# | Inland Rock                                | -             | Fraction of the 1 km^2^ grid area classified as Inland Rock, derived from UKCEH 25 m Land Cover Maps.                                                                |
# | Littoral Rock                              | -             | Fraction of the 1 km^2^ grid area classified as Littoral Rock, derived from UKCEH 25 m Land Cover Maps.                                                              |
# | Littoral sediment                          | -             | Fraction of the 1 km^2^ grid area classified as Littoral sediment, derived from UKCEH 25 m Land Cover Maps.                                                          |
# | Neutral Grassland                          | -             | Fraction of the 1 km^2^ grid area classified as Neutral Grassland, derived from UKCEH 25 m Land Cover Maps.                                                          |
# | No Land                                    | -             | Fraction of the 1 km^2^ grid area flagged as No Land, derived from UKCEH 25 m Land Cover Maps.                                                                       |
# | Saltmarsh                                  | -             | Fraction of the 1 km^2^ grid area classified as Saltmarsh, derived from UKCEH 25 m Land Cover Maps.                                                                  |
# | Saltwater                                  | -             | Fraction of the 1 km^2^ grid area classified as Saltwater, derived from UKCEH 25 m Land Cover Maps.                                                                  |
# | Suburban                                   | -             | Fraction of the 1 km^2^ grid area flagged as Suburban, derived from UKCEH 25 m Land Cover Maps.                                                                      |
# | Supra-littoral Rock                        | -             | Fraction of the 1 km^2^ grid area classified as Supra-littoral Rock, derived from UKCEH 25 m Land Cover Maps.                                                        |
# | Supra-littoral Sediment                    | -             | Fraction of the 1 km^2^ grid area classified as Supra-littoral Sediment, derived from UKCEH 25 m Land Cover Maps.                                                    |
# | Urban                                      | -             | Fraction of the 1 km^2^ grid area flagged as Urban, derived from UKCEH 25 m Land Cover Maps.                                                                         |
# | NAEI SNAP 1 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 1 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 1 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 1 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 1 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 1 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 1 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 1 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 1 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 1 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 1 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 1 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 1 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 1 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 10 CO                            | kilotonne     | Hourly emission flux of CO from SNAP sector 10 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                  |
# | NAEI SNAP 10 NH3                           | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 10 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 10 NMVOC                         | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 10 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 10 NOx                           | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 10 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 10 PM10                          | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 10 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 10 PM25                          | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 10 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                             |
# | NAEI SNAP 10 SOx                           | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 10 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 11 CO                            | kilotonne     | Hourly emission flux of CO from SNAP sector 11 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                  |
# | NAEI SNAP 11 NH3                           | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 11 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 11 NMVOC                         | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 11 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 11 NOx                           | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 11 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 11 PM10                          | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 11 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 11 PM25                          | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 11 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                             |
# | NAEI SNAP 11 SOx                           | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 11 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 2 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 2 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 2 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 2 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 2 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 2 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 2 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 2 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 2 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 2 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 2 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 2 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 2 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 2 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 3 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 3 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 3 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 3 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 3 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 3 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 3 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 3 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 3 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 3 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 3 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 3 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 3 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 3 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 4 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 4 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 4 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 4 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 4 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 4 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 4 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 4 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 4 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 4 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 4 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 4 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 4 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 4 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 5 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 5 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 5 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 5 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 5 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 5 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 5 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 5 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 5 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 5 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 5 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 5 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 5 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 5 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 6 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 6 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 6 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 6 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 6 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 6 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 6 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 6 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 6 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 6 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 6 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 6 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 6 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 6 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 7 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 7 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 7 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 7 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 7 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 7 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 7 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 7 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 7 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 7 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 7 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 7 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 7 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 7 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 8 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 8 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 8 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 8 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 8 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 8 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 8 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 8 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 8 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 8 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 8 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 8 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 8 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 8 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 9 CO                             | kilotonne     | Hourly emission flux of CO from SNAP sector 9 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                   |
# | NAEI SNAP 9 NH3                            | kilotonne     | Hourly emission flux of NH~3~ from SNAP sector 9 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 9 NMVOC                          | kilotonne     | Hourly emission flux of NMVOC from SNAP sector 9 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 9 NOx                            | kilotonne     | Hourly emission flux of NO~x~ from SNAP sector 9 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | NAEI SNAP 9 PM10                           | kilotonne     | Hourly emission flux of PM~10~ from SNAP sector 9 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                               |
# | NAEI SNAP 9 PM25                           | kilotonne     | Hourly emission flux of PM~2.5~ from SNAP sector 9 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                              |
# | NAEI SNAP 9 SOx                            | kilotonne     | Hourly emission flux of SO~x~ from SNAP sector 9 in each 1 km^2^ grid cell, aggregated from NAEI data and scaled by temporal factors.                                |
# | Road Infrastructure Distance Residential   | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Residential road, derived from OpenStreetMaps.                                                       |
# | Road Infrastructure Distance Footway       | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Footway, derived from OpenStreetMaps.                                                                |
# | Road Infrastructure Distance Service       | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Service road, derived from OpenStreetMaps.                                                           |
# | Road Infrastructure Distance Primary       | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Primary road, derived from OpenStreetMaps.                                                           |
# | Road Infrastructure Distance Path          | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Path, derived from OpenStreetMaps.                                                                   |
# | Road Infrastructure Distance Cycleway      | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Cycleway, derived from OpenStreetMaps.                                                               |
# | Road Infrastructure Distance Tertiary      | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Tertiary road, derived from OpenStreetMaps.                                                          |
# | Road Infrastructure Distance Secondary     | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Secondary road, derived from OpenStreetMaps.                                                         |
# | Road Infrastructure Distance Unclassified  | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Unclassified road, derived from OpenStreetMaps.                                                      |
# | Road Infrastructure Distance Track         | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Track, derived from OpenStreetMaps.                                                                  |
# | Road Infrastructure Distance Trunk         | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Trunk road, derived from OpenStreetMaps.                                                             |
# | Road Infrastructure Distance Motorway      | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Motorway, derived from OpenStreetMaps.                                                               |
# | Road Infrastructure Distance Pedestrian    | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Pedestrian road, derived from OpenStreetMaps.                                                        |
# | Road Infrastructure Distance Living Street | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Living Street, derived from OpenStreetMaps.                                                          |
# | Total Length Residential                   | m             | Summed length (meters) of all Residential road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                        |
# | Total Length Footway                       | m             | Summed length (meters) of all Footway segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                                 |
# | Total Length Service                       | m             | Summed length (meters) of all Service road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                            |
# | Total Length Primary                       | m             | Summed length (meters) of all Primary road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                            |
# | Total Length Path                          | m             | Summed length (meters) of all Path segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                                    |
# | Total Length Cycleway                      | m             | Summed length (meters) of all Cycleway segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                                |
# | Total Length Tertiary                      | m             | Summed length (meters) of all Tertiary road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                           |
# | Total Length Secondary                     | m             | Summed length (meters) of all Secondary road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                          |
# | Total Length Unclassified                  | m             | Summed length (meters) of all Unclassified road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                       |
# | Total Length Track                         | m             | Summed length (meters) of all Track segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                                   |
# | Total Length Trunk                         | m             | Summed length (meters) of all Trunk road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                              |
# | Total Length Motorway                      | m             | Summed length (meters) of all Motorway segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                                |
# | Total Length Pedestrian                    | m             | Summed length (meters) of all Pedestrian-classified segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                   |
# | Total Length Living Street                 | m             | Summed length (meters) of all Living Street road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                      |
# | Road Infrastructure Distance Bridleway     | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Bridleway, derived from OpenStreetMaps.                                                              |
# | Road Infrastructure Distance Construction  | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Construction road, derived from OpenStreetMaps.                                                      |
# | Road Infrastructure Distance Motorway Link | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Motorway Link, derived from OpenStreetMaps.                                                          |
# | Road Infrastructure Distance Primary Link  | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Primary Link, derived from OpenStreetMaps.                                                           |
# | Road Infrastructure Distance Raceway       | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Raceway, derived from OpenStreetMaps.                                                                |
# | Road Infrastructure Distance Secondary Link| m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Secondary Link, derived from OpenStreetMaps.                                                         |
# | Road Infrastructure Distance Steps         | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Steps, derived from OpenStreetMaps.                                                                  |
# | Road Infrastructure Distance Tertiary Link | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Tertiary Link, derived from OpenStreetMaps.                                                          |
# | Road Infrastructure Distance Trunk Link    | m             | Distance (meters) from the 1 km^2^ grid centroid to the nearest Trunk Link, derived from OpenStreetMaps.                                                             |
# | Total Length Bridleway                     | m             | Summed length (meters) of all Bridleway segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                               |
# | Total Length Construction                  | m             | Summed length (meters) of all Construction-classified road segments within each 1km^2^ grid, derived from OpenStreetMaps.                                            |
# | Total Length Motorway Link                 | m             | Summed length (meters) of all Motorway Link segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                           |
# | Total Length Primary Link                  | m             | Summed length (meters) of all Primary Link segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                            |
# | Total Length Raceway                       | m             | Summed length (meters) of all Raceway segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                                 |
# | Total Length Secondary Link                | m             | Summed length (meters) of all Secondary Link segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                          |
# | Total Length Steps                         | m             | Summed length (meters) of all Steps within each 1km^2^ grid, derived from OpenStreetMaps.                                                                            |
# | Total Length Tertiary Link                 | m             | Summed length (meters) of all Tertiary Link segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                           |
# | Total Length Trunk Link                    | m             | Summed length (meters) of all Trunk Link segments within each 1km^2^ grid, derived from OpenStreetMaps.                                                              |
